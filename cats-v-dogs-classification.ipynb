# %% [markdown]
# <a href="https://www.kaggle.com/code/ashadullah/cats-v-dogs-classification?scriptVersionId=168731296" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np # linear algebra
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,BatchNormalization,Dropout
# Out:
# 2024-03-25 18:06:31.115007: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-25 18:06:31.115108: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-25 18:06:31.250756: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
train_ds = keras.utils.image_dataset_from_directory(
    directory = '/kaggle/input/dogs-vs-cats/train',
    labels='inferred',
    label_mode='int', # Cats and dogs will get their own integer labels
    batch_size=32,
    image_size=(256,256)
)
# /kaggle/input/dogs-vs-cats/test
validation_ds = keras.utils.image_dataset_from_directory(
    directory = '/kaggle/input/dogs-vs-cats/test',
    labels='inferred',
    label_mode='int', # Cats and dogs will get their own integer labels
    batch_size=32,
    image_size=(256,256)
)
# Out:
# Found 20000 files belonging to 2 classes.
# Found 5000 files belonging to 2 classes.

# %% [markdown]
# # ways to reduce overfitting
#
# ## Add more data
# ## Data Augmentation -> next video
# ## L1/L2 Regularizer
# ## Dropout
# ## Batch Norm
# ## Reduce complexity

# %%
# Normalize
def process(image,label):
    image = tf.cast(image/255. ,tf.float32)
    return image,label

train_ds = train_ds.map(process)
validation_ds = validation_ds.map(process)

# %%
# create CNN model

model = Sequential()

model.add(Conv2D(32,kernel_size=(3,3),padding='valid',activation='relu',input_shape=(256,256,3)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(64,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Conv2D(128,kernel_size=(3,3),padding='valid',activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2),strides=2,padding='valid'))

model.add(Flatten())

model.add(Dense(128,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 254, 254, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 254, 254, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 125, 125, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 60, 60, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 115200)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    14,745,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,848,193 (56.64 MB)
#  Trainable params: 14,847,745 (56.64 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(train_ds,epochs=20,validation_data=validation_ds, verbose=0)
# Out:
# 2024-03-25 18:07:07.896633: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 5.22285, expected 4.50617
# 2024-03-25 18:07:07.896694: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 19: 4.83523, expected 4.11855
# 2024-03-25 18:07:07.896704: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 20: 6.14347, expected 5.42679
# 2024-03-25 18:07:07.896714: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 21: 5.72417, expected 5.00749
# 2024-03-25 18:07:07.896723: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 29: 6.00776, expected 5.29109
# 2024-03-25 18:07:07.896732: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 30: 5.39609, expected 4.67941
# 2024-03-25 18:07:07.896740: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 31: 5.14673, expected 4.43005
# 2024-03-25 18:07:07.896749: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 61: 5.93186, expected 5.21518
# 2024-03-25 18:07:07.896758: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 67: 6.09497, expected 5.3783
# 2024-03-25 18:07:07.896767: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 72: 4.9921, expected 4.27543
# 2024-03-25 18:07:07.925560: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,32,254,254]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,256,256]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-25 18:07:07.925620: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-25 18:07:07.925629: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-25 18:07:07.925636: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-25 18:07:07.925643: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-25 18:07:07.925660: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-03-25 18:07:08.823852: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 0: 5.22285, expected 4.50617
# 2024-03-25 18:07:08.823910: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 19: 4.83523, expected 4.11855
# 2024-03-25 18:07:08.823924: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 20: 6.14347, expected 5.42679
# 2024-03-25 18:07:08.823936: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 21: 5.72417, expected 5.00749
# 2024-03-25 18:07:08.823952: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 29: 6.00776, expected 5.29109
# 2024-03-25 18:07:08.823967: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 30: 5.39609, expected 4.67941
# 2024-03-25 18:07:08.823978: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 31: 5.14673, expected 4.43005
# 2024-03-25 18:07:08.823989: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 61: 5.93186, expected 5.21518
# 2024-03-25 18:07:08.823999: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 67: 6.09497, expected 5.3783
# 2024-03-25 18:07:08.824010: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 72: 4.9921, expected 4.27543
# 2024-03-25 18:07:08.853820: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[32,32,254,254]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,3,256,256]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-25 18:07:08.853856: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-25 18:07:08.853870: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-25 18:07:08.853880: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-25 18:07:08.853890: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-25 18:07:08.853916: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1711390036.281038      75 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-03-25 18:07:58.592442: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129032: 6.56968, expected 5.72998
# 2024-03-25 18:07:58.592504: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129051: 7.10358, expected 6.26388
# 2024-03-25 18:07:58.592514: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129052: 6.99086, expected 6.15116
# 2024-03-25 18:07:58.592522: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129062: 7.37213, expected 6.53244
# 2024-03-25 18:07:58.592530: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129063: 6.0521, expected 5.2124
# 2024-03-25 18:07:58.592538: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129064: 7.1427, expected 6.30301
# 2024-03-25 18:07:58.592546: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129072: 7.38607, expected 6.54637
# 2024-03-25 18:07:58.592554: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129098: 7.18015, expected 6.34045
# 2024-03-25 18:07:58.592562: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129104: 7.04205, expected 6.20235
# 2024-03-25 18:07:58.592570: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129105: 7.05266, expected 6.21296
# 2024-03-25 18:07:58.599931: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[8,32,254,254]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,3,256,256]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-25 18:07:58.599963: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-25 18:07:58.599972: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-25 18:07:58.599979: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-25 18:07:58.599986: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-25 18:07:58.600001: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-03-25 18:07:58.822720: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129032: 6.56968, expected 5.72998
# 2024-03-25 18:07:58.822763: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129051: 7.10358, expected 6.26388
# 2024-03-25 18:07:58.822772: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129052: 6.99086, expected 6.15116
# 2024-03-25 18:07:58.822780: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129062: 7.37213, expected 6.53244
# 2024-03-25 18:07:58.822788: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129063: 6.0521, expected 5.2124
# 2024-03-25 18:07:58.822796: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129064: 7.1427, expected 6.30301
# 2024-03-25 18:07:58.822804: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129072: 7.38607, expected 6.54637
# 2024-03-25 18:07:58.822812: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129098: 7.18015, expected 6.34045
# 2024-03-25 18:07:58.822819: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129104: 7.04205, expected 6.20235
# 2024-03-25 18:07:58.822827: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 129105: 7.05266, expected 6.21296
# 2024-03-25 18:07:58.829979: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[8,32,254,254]{3,2,1,0}, u8[0]{0}) custom-call(f32[8,3,256,256]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-25 18:07:58.830011: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-25 18:07:58.830020: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-25 18:07:58.830026: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-25 18:07:58.830034: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-25 18:07:58.830049: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'],color='red',label='train')
plt.plot(history.history['val_accuracy'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
plt.plot(history.history['loss'],color='red',label='train')
plt.plot(history.history['val_loss'],color='blue',label='validation')
plt.legend()
plt.show()

# %%
import cv2

# %%
test_img = cv2.imread('/kaggle/input/dogs-vs-cats/train/cats/cat.1043.jpg')

# %%
plt.imshow(test_img)

# %%
test_img.shape
# Out:
# (374, 500, 3)

# %%
test_img = cv2.resize(test_img,(256,256))

# %%
test_input = test_img.reshape((1,256,256,3))

# %%
model.predict(test_input)
# Out:
# 2024-03-25 18:17:42.250892: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387127: 5.77154, expected 5.03187
# 2024-03-25 18:17:42.250946: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387168: 6.05753, expected 5.31786
# 2024-03-25 18:17:42.250956: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387274: 5.79451, expected 5.05483
# 2024-03-25 18:17:42.250964: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387303: 6.3865, expected 5.64683
# 2024-03-25 18:17:42.250974: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387310: 6.3852, expected 5.64553
# 2024-03-25 18:17:42.250982: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387370: 6.37416, expected 5.63449
# 2024-03-25 18:17:42.250990: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387381: 4.72788, expected 3.98821
# 2024-03-25 18:17:42.250998: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387382: 5.98635, expected 5.24668
# 2024-03-25 18:17:42.251005: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387394: 6.14397, expected 5.4043
# 2024-03-25 18:17:42.251013: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387396: 6.24704, expected 5.50736
# 2024-03-25 18:17:42.251029: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,32,254,254]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,256,256]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-25 18:17:42.251037: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-25 18:17:42.251045: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-25 18:17:42.251051: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-25 18:17:42.251058: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-25 18:17:42.251069: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 2024-03-25 18:17:42.310875: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387127: 5.77154, expected 5.03187
# 2024-03-25 18:17:42.310920: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387168: 6.05753, expected 5.31786
# 2024-03-25 18:17:42.310930: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387274: 5.79451, expected 5.05483
# 2024-03-25 18:17:42.310939: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387303: 6.3865, expected 5.64683
# 2024-03-25 18:17:42.310947: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387310: 6.3852, expected 5.64553
# 2024-03-25 18:17:42.310956: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387370: 6.37416, expected 5.63449
# 2024-03-25 18:17:42.310964: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387381: 4.72788, expected 3.98821
# 2024-03-25 18:17:42.310973: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387382: 5.98635, expected 5.24668
# 2024-03-25 18:17:42.310981: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387394: 6.14397, expected 5.4043
# 2024-03-25 18:17:42.310989: E external/local_xla/xla/service/gpu/buffer_comparator.cc:1137] Difference at 387396: 6.24704, expected 5.50736
# 2024-03-25 18:17:42.311006: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:705] Results mismatch between different convolution algorithms. This is likely a bug/unexpected loss of precision in cudnn.
# (f32[1,32,254,254]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,3,256,256]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"conv_result_scale":1,"activation_mode":"kRelu","side_input_scale":0,"leakyrelu_alpha":0} for eng20{k2=2,k4=1,k5=1,k6=0,k7=0} vs eng15{k5=1,k6=0,k7=1,k10=1}
# 2024-03-25 18:17:42.311015: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:270] Device: Tesla P100-PCIE-16GB
# 2024-03-25 18:17:42.311022: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:271] Platform: Compute Capability 6.0
# 2024-03-25 18:17:42.311029: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:272] Driver: 12020 (535.129.3)
# 2024-03-25 18:17:42.311037: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:273] Runtime: <undefined>
# 2024-03-25 18:17:42.311053: E external/local_xla/xla/service/gpu/conv_algorithm_picker.cc:280] cudnn version: 8.9.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 732ms/step
# array([[1.]], dtype=float32)

# %%
# now for dog it should returns array[1]
test_img = cv2.imread('/kaggle/input/dogs-vs-cats/train/dogs/dog.6813.jpg')

# %%
plt.imshow(test_img)

# %%
test_img.shape
# Out:
# (258, 242, 3)

# %%
test_img = cv2.resize(test_img,(256,256))

# %%
test_input = test_img.reshape((1,256,256,3))

# %%
model.predict(test_input)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# array([[1.]], dtype=float32)
